# %% [markdown]
# Objetivo:
# Investigar a distribuição de skateparks no Brasil e possíveis desigualdades de acesso.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/processed/skateparks.csv")
df.head()
# Out:
#      osm_id                             name city  state        lat        lon
# 0  24261962                              NaN  NaN    NaN  -1.050145 -46.760852
# 1  30420455  Skatepark do Aterro do Flamengo  NaN    NaN -22.924732 -43.170552
# 2  49826065                       Skate Rink  NaN    NaN -22.813151 -43.207624
# 3  51943883                              NaN  NaN    NaN -20.299687 -40.291821
# 4  59147230                              NaN  NaN    NaN -13.002697 -38.451209

# %%
df.shape
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   osm_id  1266 non-null   int64
#  1   name    307 non-null    str
#  2   city    10 non-null     str
#  3   state   0 non-null      float64
#  4   lat     1266 non-null   float64
#  5   lon     1266 non-null   float64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 59.5 KB
# osm_id       0
# name       959
# city      1256
# state     1266
# lat          0
# lon          0
# dtype: int64

# %%
len(df)
# Out:
# 1266

# %%
df[["city", "state"]].sample(20)
# Out:
#      city  state
# 840   NaN    NaN
# 273   NaN    NaN
# 332   NaN    NaN
# 923   NaN    NaN
# 720   NaN    NaN
# 295   NaN    NaN
# 388   NaN    NaN
# 501   NaN    NaN
# 7     NaN    NaN
# 983   NaN    NaN
# 1104  NaN    NaN
# 967   NaN    NaN
# 844   NaN    NaN
# 247   NaN    NaN
# 1024  NaN    NaN
# 900   NaN    NaN
# 778   NaN    NaN
# 126   NaN    NaN
# 1004  NaN    NaN
# 531   NaN    NaN

# %%
df.isnull().sum()
# Out:
# osm_id       0
# name       959
# city      1256
# state     1266
# lat          0
# lon          0
# dtype: int64

# %% [markdown]
# Observation:
# Administrative metadata (city/state) is mostly missing in OSM records.
# Analysis will rely primarily on geographic coordinates in the MVP.

# %%
df[["lat", "lon"]].describe()
# Out:
#                lat          lon
# count  1266.000000  1266.000000
# mean    -20.359373   -46.672978
# std       7.226611     5.240849
# min     -32.557026   -72.681802
# 25%     -23.747309   -49.350791
# 50%     -22.783286   -47.183737
# 75%     -18.851990   -43.544638
# max       2.838525   -34.800329

# %%
plt.scatter(df["lon"], df["lat"], alpha=0.5)

plt.show()

# %% [markdown]
# perguntar ao chat:
# 1. o que sao essas analises feitas ate agora
# 2. algumas pastas como data.processed, data.raw não estão existindo no remoto
